# %%
import mysql.connector
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
db_connection_str = 'mysql+mysqlconnector://root:EsUnaPrueba123@localhost/hello_mysql'
#lenguaje y tipo de conexión, user, contraseña, host y base de datos
db_connection = create_engine(db_connection_str)
sql_query = 'SELECT conteo,gender FROM prueba'
df = pd.read_sql(sql_query, con=db_connection)
db_connection.dispose()
print(df)
# Out:
#         conteo      gender
# 0    51.768145  No binarie
# 1   174.519412    Femenino
# 2   172.819993    Femenino
# 3   223.629310    Femenino
# 4   147.734205    Femenino
# 5   294.029364    Femenino
# 6    45.467519  No binarie
# 7   231.967639    Femenino
# 8   269.057474   Masculino
# 9    57.946266   Masculino
# 10  178.553185   Masculino
# 11  212.895758    Femenino
# 12  234.729622   Masculino
# 13  195.846416  No binarie
# 14  225.359932   Masculino
# 15  217.173411  No binarie
# 16  107.945738   Masculino
# 17  180.983020   Masculino
# 18  267.481473    Femenino
# 19  181.095627   Masculino
# 20  265.079368   Masculino
# 21  250.010901    Femenino
# 22  133.096185   Masculino
# 23  113.338559   Masculino
# 24  236.551410   Masculino
# 25  205.584299    Femenino
# 26  226.811515   Masculino
# 27  341.742987   Masculino
# 28  177.236210    Femenino
# 29  109.883611    Femenino
# 30  192.473066   Masculino
# 31  260.893757    Femenino
# 32  233.488064   Masculino
# ...

# %%
config = mysql.connector.connect(
    host="localhost",
    user="root",
    password="EsUnaPrueba123",
    database="hello_mysql"
)

print(config)

# %%
sql_query = 'SELECT * FROM useres'

# Use pandas.read_sql() to fetch data into a DataFrame
df = pd.read_sql(sql_query, con=config)

# Optional: Close the connection
config.close()

# Print the DataFrame
print(df)
# Out:
#    users_id    name surname   age      inicio
# 0         1    juan   perez  27.0  2015-12-01
# 1         2    juan    None   NaN        None
# 2         3  Sergio    None  32.0        None
# 3         4  Sergio    None  32.0        None
# 4         5  Sergio    None  32.0  2015-01-01
# C:\Users\praxy\AppData\Local\Temp\ipykernel_25440\1925138361.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql_query, con=config)

# %%
mycursor = config.cursor()
#el cursor() es una clase para operar la conexión
#mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")

# %%
type(mycursor)
# Out:
# mysql.connector.cursor_cext.CMySQLCursor

# %%
mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# ('amigos',)
# ('customers',)
# ('estudiantes',)
# ('prueba',)
# ('salario',)
# ('useres',)

# %%
mycursor.execute("ALTER TABLE customers ADD COLUMN id INT AUTO_INCREMENT PRIMARY KEY")

# %%
sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = ("John", "Highway 21")
mycursor.execute(sql, val)

config.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.

# %%
sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = [
  ('Peter', 'Lowstreet 4'),
  ('Amy', 'Apple st 652'),
  ('Hannah', 'Mountain 21'),
  ('Michael', 'Valley 345'),
  ('Sandy', 'Ocean blvd 2'),
  ('Betty', 'Green Grass 1'),
  ('Richard', 'Sky st 331'),
  ('Susan', 'One way 98'),
  ('Vicky', 'Yellow Garden 2'),
  ('Ben', 'Park Lane 38'),
  ('William', 'Central st 954'),
  ('Chuck', 'Main Road 989'),
  ('Viola', 'Sideway 1633')
]

mycursor.executemany(sql, val)

config.commit()

print(mycursor.rowcount, "was inserted.")
# Out:
# 13 was inserted.

# %%
print(mycursor.lastrowid)
#retorna el ID de la primera fila del último execute
# Out:
# 3

# %%
mycursor.execute("SELECT * FROM customers")

myresult = mycursor.fetchall()
#fetchall es para aplicar a todas las filas del último execute 
for x in myresult:
  print(x)
# Out:
# ('John', 'Highway 21', 1)
# ('John', 'Highway 21', 2)
# ('Peter', 'Lowstreet 4', 3)
# ('Amy', 'Apple st 652', 4)
# ('Hannah', 'Mountain 21', 5)
# ('Michael', 'Valley 345', 6)
# ('Sandy', 'Ocean blvd 2', 7)
# ('Betty', 'Green Grass 1', 8)
# ('Richard', 'Sky st 331', 9)
# ('Susan', 'One way 98', 10)
# ('Vicky', 'Yellow Garden 2', 11)
# ('Ben', 'Park Lane 38', 12)
# ('William', 'Central st 954', 13)
# ('Chuck', 'Main Road 989', 14)
# ('Viola', 'Sideway 1633', 15)

# %%
print(myresult)
# Out:
# ('John', 'Highway 21', 1)

# %%
mycursor.execute("SELECT name, address FROM customers")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('John', 'Highway 21')
# ('John', 'Highway 21')
# ('Peter', 'Lowstreet 4')
# ('Amy', 'Apple st 652')
# ('Hannah', 'Mountain 21')
# ('Michael', 'Valley 345')
# ('Sandy', 'Ocean blvd 2')
# ('Betty', 'Green Grass 1')
# ('Richard', 'Sky st 331')
# ('Susan', 'One way 98')
# ('Vicky', 'Yellow Garden 2')
# ('Ben', 'Park Lane 38')
# ('William', 'Central st 954')
# ('Chuck', 'Main Road 989')
# ('Viola', 'Sideway 1633')

# %%
mycursor.execute("SELECT * FROM customers")

myresult = mycursor.fetchone()

print(myresult)
# Out:
# ('John', 'Highway 21', 1)

# %%
sql = "SELECT * FROM customers WHERE address LIKE '%way%'"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('John', 'Highway 21', 1)
# ('John', 'Highway 21', 2)
# ('Susan', 'One way 98', 10)
# ('Viola', 'Sideway 1633', 15)

# %%
sql = "SELECT * FROM customers WHERE address = %s"
adr = ("Yellow Garden 2",)

mycursor.execute(sql, adr)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Vicky', 'Yellow Garden 2', 11)

# %%
sql = "UPDATE customers SET address = 'Canyon 123' WHERE address = 'Valley 345'"

mycursor.execute(sql)

config.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected

# %%
import utils.query as q
from utils.conection import mysql_connector_connection

config=mysql_connector_connection()
mycursor=config.cursor()
sql = "UPDATE prueba SET estado = 'deteriorado' WHERE estado = 'en deterioro'"

q.query_commit(sql,mycursor,config)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from utils.query import query_commit
#       2 from utils.conection import mysql_connector_connection
#       4 config=mysql_connector_connection()
#
# ImportError: cannot import name 'query_commit' from 'utils.query' (c:\Users\praxy\OneDrive\Escritorio\Progra\Budget_app\utils\query.py)

# %%
sql = "DELETE FROM customers WHERE address = 'Mountain 21'"

mycursor.execute(sql)

config.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 1 record(s) deleted

# %%
sql = "DROP TABLE IF EXISTS customers"

mycursor.execute(sql)

# %%
#hay que cerrar el cursor
mycursor.close()
